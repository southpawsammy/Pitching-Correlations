# %%
import pandas as pd

# %%
bullpen = pd.read_csv('pitchingAVGBreaks.csv')

# %%
bullpen
# Out:
#     last_name  first_name  year    xba  exit_velocity_avg  \
# 0     Perdomo        Luis  2019  0.264               89.4
# 1      Rondon      Hector  2019  0.230               86.8
# 2        Pena       Felix  2019  0.254               88.7
# 3      Pineda     Michael  2019  0.258               88.9
# 4     Keuchel      Dallas  2019  0.268               88.0
# ..        ...         ...   ...    ...                ...
# 274     Maeda       Kenta  2019  0.216               85.4
# 275     Lamet    Dinelson  2019  0.217               86.9
# 276   Newcomb        Sean  2019  0.237               86.9
# 277    Peters      Dillon  2019  0.285               89.0
# 278    Valdez     Framber  2019  0.253               89.5
#
#      z_swing_miss_percent  oz_swing_miss_percent  fastball_avg_break  \
# 0                    11.5                   37.4                18.0
# 1                    14.6                   41.7                17.6
# ...

# %%
bullpen.corr()
# Out:
#                        year       xba  exit_velocity_avg  \
# year                    NaN       NaN                NaN
# xba                     NaN  1.000000           0.327478
# exit_velocity_avg       NaN  0.327478           1.000000
# z_swing_miss_percent    NaN -0.745505          -0.195259
# oz_swing_miss_percent   NaN -0.572947           0.062843
# fastball_avg_break      NaN -0.245562          -0.023254
# breaking_avg_break      NaN -0.078339          -0.109628
# offspeed_avg_break      NaN -0.187374          -0.178411
# Unnamed: 10             NaN       NaN                NaN
#
#                        z_swing_miss_percent  oz_swing_miss_percent  \
# year                                    NaN                    NaN
# xba                               -0.745505              -0.572947
# exit_velocity_avg                 -0.195259               0.062843
# z_swing_miss_percent               1.000000               0.489114
# ...

# %%
bullpen.shape
# Out:
# (279, 11)

# %%
bullpen.corr(method = 'spearman')
# Out:
#                        year       xba  exit_velocity_avg  \
# year                    NaN       NaN                NaN
# xba                     NaN  1.000000           0.349769
# exit_velocity_avg       NaN  0.349769           1.000000
# z_swing_miss_percent    NaN -0.736458          -0.268416
# oz_swing_miss_percent   NaN -0.552811           0.051345
# fastball_avg_break      NaN -0.257956          -0.015849
# breaking_avg_break      NaN -0.067050          -0.108329
# offspeed_avg_break      NaN -0.214593          -0.157352
# Unnamed: 10             NaN       NaN                NaN
#
#                        z_swing_miss_percent  oz_swing_miss_percent  \
# year                                    NaN                    NaN
# xba                               -0.736458              -0.552811
# exit_velocity_avg                 -0.268416               0.051345
# z_swing_miss_percent               1.000000               0.477798
# ...

# %%
bullpen.corr(method = 'kendall')
# Out:
#                        year       xba  exit_velocity_avg  \
# year                    1.0       NaN                NaN
# xba                     NaN  1.000000           0.240323
# exit_velocity_avg       NaN  0.240323           1.000000
# z_swing_miss_percent    NaN -0.551021          -0.187132
# oz_swing_miss_percent   NaN -0.391485           0.032763
# fastball_avg_break      NaN -0.173404          -0.010672
# breaking_avg_break      NaN -0.044147          -0.072851
# offspeed_avg_break      NaN -0.142753          -0.107968
# Unnamed: 10             NaN       NaN                NaN
#
#                        z_swing_miss_percent  oz_swing_miss_percent  \
# year                                    NaN                    NaN
# xba                               -0.551021              -0.391485
# exit_velocity_avg                 -0.187132               0.032763
# z_swing_miss_percent               1.000000               0.330841
# ...
